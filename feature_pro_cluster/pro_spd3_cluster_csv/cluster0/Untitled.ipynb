# %%
import pandas as pd

# %%
data_path = "ID1091_spd3.csv"

# %%
with open(data_path, 'r') as f:
    data1 = pd.read_csv(f)

# %%
data1
# Out:
#                SEQ        M        T        D        L        E        K  \
# 0              ASA  142.100  101.700   98.900  103.700  139.500  117.300
# 1              Phi  -95.000  -93.100  -90.700  -80.400  -87.000  -92.600
# 2              Psi  132.600  130.400  115.100  -10.000   54.400  130.600
# 3  Theta(i-1=>i+1)  115.100  113.600  110.600  100.900  106.500  115.800
# 4    Tau(i-2=>i+2)  164.700 -153.600 -139.700 -174.400   85.900  176.600
# 5     HSE_alpha_up    5.200    4.500    5.300    7.700    2.800    7.200
# 6   HSE_alpha_down    6.300    9.500   13.200    9.800   11.200   11.700
# 7             P(C)    0.995    0.983    0.977    0.947    0.931    0.948
# 8             P(H)    0.003    0.008    0.010    0.036    0.042    0.023
# 9             P(E)    0.002    0.010    0.013    0.017    0.027    0.028
#
#          P        S       I   ...       V.41    L.42    Y.24     K.37  \
# 0   76.500   74.500   68.30   ...     68.200  79.200  84.900  105.100
# ...

# %%
data_path = "ID20_spd3.csv"

# %%
with open(data_path, 'r') as f:
    data2 = pd.read_csv(f)

# %%
data2
# Out:
#                SEQ        M        S      S.1        K        C        D  \
# 0              ASA  133.600   81.800   59.700  103.800   11.500   45.600
# 1              Phi  -93.700  -90.800  -93.700 -103.600 -120.700  -81.000
# 2              Psi  130.700  126.400  120.900  129.300  145.500  -23.100
# 3  Theta(i-1=>i+1)  114.500  112.000  112.400  117.100  128.600   98.400
# 4    Tau(i-2=>i+2)  157.300 -138.800 -147.300 -167.200 -172.900 -147.300
# 5     HSE_alpha_up    6.600    5.100   10.300    9.200   22.700   14.400
# 6   HSE_alpha_down    8.500   12.100   14.900   19.600   18.000   25.600
# 7             P(C)    0.987    0.967    0.929    0.867    0.658    0.719
# 8             P(H)    0.008    0.021    0.031    0.014    0.005    0.002
# 9             P(E)    0.005    0.012    0.041    0.119    0.337    0.279
#
#          V      V.1      V.2   ...       A.31    H.15   K.30     R.26  \
# 0    2.300    0.900    0.600   ...     29.000  99.200  131.6  124.300
# ...

# %%
data = [data1, data2]

# %%
data
# Out:
# [               SEQ        M        T        D        L        E        K  \
#  0              ASA  142.100  101.700   98.900  103.700  139.500  117.300
#  1              Phi  -95.000  -93.100  -90.700  -80.400  -87.000  -92.600
#  2              Psi  132.600  130.400  115.100  -10.000   54.400  130.600
#  3  Theta(i-1=>i+1)  115.100  113.600  110.600  100.900  106.500  115.800
#  4    Tau(i-2=>i+2)  164.700 -153.600 -139.700 -174.400   85.900  176.600
#  5     HSE_alpha_up    5.200    4.500    5.300    7.700    2.800    7.200
#  6   HSE_alpha_down    6.300    9.500   13.200    9.800   11.200   11.700
#  7             P(C)    0.995    0.983    0.977    0.947    0.931    0.948
#  8             P(H)    0.003    0.008    0.010    0.036    0.042    0.023
#  9             P(E)    0.002    0.010    0.013    0.017    0.027    0.028
#
#           P        S       I   ...       V.41    L.42    Y.24     K.37  \
#  0   76.500   74.500   68.30   ...     68.200  79.200  84.900  105.100
# ...

# %%
import numpy as np
data = np.array(data)
print(data[1])
# Out:
#                SEQ        M        S      S.1        K        C        D  \
# 0              ASA  133.600   81.800   59.700  103.800   11.500   45.600
# 1              Phi  -93.700  -90.800  -93.700 -103.600 -120.700  -81.000
# 2              Psi  130.700  126.400  120.900  129.300  145.500  -23.100
# 3  Theta(i-1=>i+1)  114.500  112.000  112.400  117.100  128.600   98.400
# 4    Tau(i-2=>i+2)  157.300 -138.800 -147.300 -167.200 -172.900 -147.300
# 5     HSE_alpha_up    6.600    5.100   10.300    9.200   22.700   14.400
# 6   HSE_alpha_down    8.500   12.100   14.900   19.600   18.000   25.600
# 7             P(C)    0.987    0.967    0.929    0.867    0.658    0.719
# 8             P(H)    0.008    0.021    0.031    0.014    0.005    0.002
# 9             P(E)    0.005    0.012    0.041    0.119    0.337    0.279
#
#          V      V.1      V.2   ...       A.31    H.15   K.30     R.26  \
# 0    2.300    0.900    0.600   ...     29.000  99.200  131.6  124.300
# ...
